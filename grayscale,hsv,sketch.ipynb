# %%
#grayscale
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

img = mpimg.imread('pandaim.jfif')

gray = rgb2gray(img)

plt.imshow(gray, cmap='gray')

plt.savefig('greyscale.png')
plt.show()

# %%
#HSV

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
  
  
image = mpimg.imread('pandaim.jfif')
plt.title("Output image")
  
  
hsv = matplotlib.colors.rgb_to_hsv(image)
plt.imshow(hsv)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pip install OpenCV-python
# Out:
# Requirement already satisfied: OpenCV-python in c:\users\u1138648\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\u1138648\anaconda3\lib\site-packages (from OpenCV-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#sketch
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
gvn_image = cv2.imread("pandaim.jfif")
gvn_image = cv2.cvtColor(gvn_image, cv2.COLOR_BGR2RGB)
grayscle_image = cv2.cvtColor(gvn_image, cv2.COLOR_BGR2GRAY)
invertd_image = cv2.bitwise_not(grayscle_image)
smooth_image = cv2.GaussianBlur(invertd_image, (21, 21),sigmaX=0, sigmaY=0)


pencil_skecth = cv2.divide(grayscle_image, 255 - smooth_image, scale=255)
plt.imshow(pencil_skecth, cmap="gray")
plt.title("Output Pencil Sketch Image")
plt.show()
